# %%
# This program imports the dependencies.
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
# import dataset
lr_data = pd.read_csv('/home/nathan/machinelearning/data/external/data_for_lr.csv')

# %%
# This code display the five first row of the dataset
lr_data.head()
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398
# 4  87.0  87.288984

# %%
# This code checking the shape
lr_data.shape
# Out:
# (700, 2)

# %%
# This code display the dataset info
lr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
# This code checks for missing values
lr_data.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
# This code provide some statistical measures about the dataset
lr_data.describe()
# Out:
#         model_year
# count  4009.000000
# mean   2015.515590
# std       6.104816
# min    1974.000000
# 25%    2012.000000
# 50%    2017.000000
# 75%    2020.000000
# max    2024.000000

# %%
# This code import the data Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# This code shows distribution plot for all other columns
for column in lr_data:
    sns.displot(x=column, data=lr_data)

# %%
# This code shows paitplot
sns.pairplot(lr_data)

# %%
# This code compute the outliers
for column in lr_data:
    plt.figure()
    lr_data.boxplot([column])

# %%
# This code compute the Correlation matrix
correlation_matrix = lr_data.corr()
plt.figure(figsize=(20,20))
sns.heatmap(correlation_matrix, cbar=True, fmt='.1f', annot=True, cmap='Blues')
plt.savefig('Correlation Heat map')
